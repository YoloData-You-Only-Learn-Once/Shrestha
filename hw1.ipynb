# %%
import pandas as pd

# %%
df = pd.read_csv("conversion_data.csv")
# df[:10]
df.ix[:10]
# Out:
#    country  age  new_user  source  total_pages_visited  converted
# 0       UK   25         1     Ads                    1          0
# 1       US   23         1     Seo                    5          0
# 2       US   28         1     Seo                    4          0
# 3    China   39         1     Seo                    5          0
# 4       US   30         1     Seo                    6          0
# 5       US   31         0     Seo                    1          0
# 6    China   27         1     Seo                    4          0
# 7       US   23         0     Ads                    4          0
# 8       UK   29         0  Direct                    4          0
# 9       US   25         0     Ads                    2          0
# 10      US   38         0     Seo                    1          0

# %%
# df.loc[df['age']< 30]
df.sort(['age'],ascending=[False])
# df.sort(['age'], ascending=[False])[:10]
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#         country  age  new_user  source  total_pages_visited  converted
# 90928   Germany  123         0     Seo                   15          1
# 295581       UK  111         0     Ads                   10          1
# 265167       US   79         1  Direct                    1          0
# 192644       US   77         0  Direct                    4          0
# 154217       US   73         1     Seo                    5          0
# 208969       US   72         1  Direct                    4          0
# 301366       UK   70         0     Ads                    5          0
# 114485       US   70         1     Ads                    9          0
# 57122        UK   69         1  Direct                    4          0
# 290142       US   69         1     Seo                    6          0
# ...

# %%
df['age'].max()
# Out:
# 123

# %%
df['age'].describe()
# Out:
# count    316200.000000
# mean         30.569858
# std           8.271802
# min          17.000000
# 25%          24.000000
# 50%          30.000000
# 75%          36.000000
# max         123.000000
# Name: age, dtype: float64

# %%
# df.groupby(['age', 'converted']).size()

# %%
df['country'].describe()
# Out:
# count     316200
# unique         4
# top           US
# freq      178092
# Name: country, dtype: object

# %%
df.groupby(['country', 'converted']).size()
# Out:
# country  converted
# China    0             76500
#          1               102
# Germany  0             12240
#          1               816
# UK       0             45900
#          1              2550
# US       0            171360
#          1              6732
# dtype: int64

# %%
df.groupby(['country', 'converted']).size().groupby(['country'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Applications/anaconda/lib/python3.5/site-packages/pandas/indexes/multi.py in get_value(self, series, key)
#     617             try:
# --> 618                 return _index.get_value_at(s, k)
#     619             except IndexError:
#
# pandas/index.pyx in pandas.index.get_value_at (pandas/index.c:2549)()
#
# pandas/src/util.pxd in util.get_value_at (pandas/index.c:13159)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-63df6ba4e2a9> in <module>()
# ----> 1 df.groupby(['country', 'converted']).size().groupby(['country'])
#
# ...

# %%
df.source.value_counts().plot('bar')
#ggplot
df.group_country().mean()
